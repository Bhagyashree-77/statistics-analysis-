# %%
import pandas as pd

# %%
data=pd.read_csv("C:\\Users\\BHAGYASHREE\\Downloads\\cars.csv")

# %%
data
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data.head()
# Out:
#           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
data.tail()
# Out:
#         Unnamed: 0   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %%
data.sample(3)
# Out:
#            Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 20      Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 16  Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 22        AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
#
#     gear  carb
# 20     3     1
# 16     3     4
# 22     3     2

# %%
data['mpg']
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
data.shape
# Out:
# (32, 12)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs',
#        'am', 'gear', 'carb'],
#       dtype='object')

# %%
data.size
# Out:
# 384

# %%
32*12
# Out:
# 384

# %%
df_numerical=data[['disp','hp','drat']]

# %%
df_numerical.head()
# Out:
#     disp   hp  drat
# 0  160.0  110  3.90
# 1  160.0  110  3.90
# 2  108.0   93  3.85
# 3  258.0  110  3.08
# 4  360.0  175  3.15

# %%
df_category=data[['Unnamed: 0','mpg','cyl','wt','qsec','vs','am','gear','carb']]

# %%
df_category.head()
# Out:
#           Unnamed: 0   mpg  cyl     wt   qsec  vs  am  gear  carb
# 0          Mazda RX4  21.0    6  2.620  16.46   0   1     4     4
# 1      Mazda RX4 Wag  21.0    6  2.875  17.02   0   1     4     4
# 2         Datsun 710  22.8    4  2.320  18.61   1   1     4     1
# 3     Hornet 4 Drive  21.4    6  3.215  19.44   1   0     3     1
# 4  Hornet Sportabout  18.7    8  3.440  17.02   0   0     3     2

# %%
data[data['mpg']<20]
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# ...

# %%
data.sort_values(by='disp')
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 29         Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.50   0   1
# ...

# %%
data.sort_values(by='mpg')
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# ...

# %%
data.sort_values(by='wt', ascending=False)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# ...

# %% [markdown]
# #GROUP BY IN DATA

# %%
##data.groupby('mpg').mean()

# %%
data['mpg'].value_counts()
# Out:
# mpg
# 21.0    2
# 19.2    2
# 30.4    2
# 22.8    2
# 15.2    2
# 10.4    2
# 21.4    2
# 33.9    1
# 19.7    1
# 15.8    1
# 26.0    1
# 27.3    1
# 13.3    1
# 15.5    1
# 21.5    1
# 24.4    1
# 14.3    1
# 32.4    1
# 14.7    1
# 18.7    1
# 18.1    1
# 17.3    1
# 16.4    1
# 17.8    1
# 15.0    1
# Name: count, dtype: int64

# %%
data.merge(df_category,on='wt')
# Out:
#            Unnamed: 0_x  mpg_x  cyl_x   disp   hp  drat     wt  qsec_x  vs_x  \
# 0             Mazda RX4   21.0      6  160.0  110  3.90  2.620   16.46     0
# 1         Mazda RX4 Wag   21.0      6  160.0  110  3.90  2.875   17.02     0
# 2            Datsun 710   22.8      4  108.0   93  3.85  2.320   18.61     1
# 3        Hornet 4 Drive   21.4      6  258.0  110  3.08  3.215   19.44     1
# 4     Hornet Sportabout   18.7      8  360.0  175  3.15  3.440   17.02     0
# 5     Hornet Sportabout   18.7      8  360.0  175  3.15  3.440   17.02     0
# 6     Hornet Sportabout   18.7      8  360.0  175  3.15  3.440   17.02     0
# 7              Merc 280   19.2      6  167.6  123  3.92  3.440   18.30     1
# 8              Merc 280   19.2      6  167.6  123  3.92  3.440   18.30     1
# 9              Merc 280   19.2      6  167.6  123  3.92  3.440   18.30     1
# 10            Merc 280C   17.8      6  167.6  123  3.92  3.440   18.90     1
# ...

# %%
data.pivot_table(index='disp',columns='drat',values='wt')
# Out:
# drat   2.76  2.93   3.00  3.07   3.08   3.15  3.21   3.23  3.54  3.62  ...  \
# disp                                                                   ...
# 71.1    NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 75.7    NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 78.7    NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 79.0    NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 95.1    NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 108.0   NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 120.1   NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 120.3   NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 121.0   NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# 140.8   NaN   NaN    NaN   NaN    NaN    NaN   NaN    NaN   NaN   NaN  ...
# ...

# %% [markdown]
# ##HANDLING MISSING VALUES --Bold--

# %%
data.dropna()
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
##data.fillna(data.mean())

# %%
data.fillna(value=0)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
data.fillna(data.mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 data_numerical=data.fillna(data_numerical.mean())
#
# NameError: name 'data_numerical' is not defined

# %%
t=data['mpg'][0:10]
print(t)
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# 5    18.1
# 6    14.3
# 7    24.4
# 8    22.8
# 9    19.2
# Name: mpg, dtype: float64

# %%
data['wt']=data['wt'].astype(str)
